# %%
import pandas as pd
import japanize_matplotlib

df=pd.read_excel('data_1-3.xlsx')
display(df)
# Out:
#    名前  年齢   購入額
# 0  佐藤  21  9000
# 1  斎藤  30  8200
# 2  鈴木  18  1200
# 3  田中  26  5000

# %%
df.plot(x='名前',y='購入額',kind='bar')
# Out:
# <Axes: xlabel='名前'>
